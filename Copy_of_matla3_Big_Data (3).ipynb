# %%
#@title ## Big Data Lab  - Assignment 3  - Preparing and Exploratory Analysis of Data
#@markdown ### Instructions
#@markdown 1. The purpose of this assignment is to cover the necessary EDA skills
#@markdown  you need to dominate in order to handle the course material.
#@markdown 2. You can choose to complete the assignment on your own or to colaborate with a partner. You are welcome to discuss your work with your fellow students but to maintain a healthy learning process - please keep all final answers to yourself!
#@markdown 3. Complete the answers in the empty cells - Feel free to add as many extra cell as you require.
#@markdown 4. Fill in your name and select the Year and Department.
#@markdown 5. When done - Download the colab notebook by going to 'File -> Download .ipynb' and submit the file in the course's moodle page before the due date.

#@markdown ---
#@markdown ### Enter your information:
Student1_Full_Name = "Ali Hamed" #@param {type:"string"}
Student2_Full_Name = "Mohamad Ganam" #@param {type:"string"}
Department = "Computer Science" #@param ["Select","Computer Science", "Industrial Engineering", "Economics and Management"]
Year = "Second" #@param ["Select","Second", "Third", "Fourth"]

#@markdown ---

# %% [markdown]
# 1. Import the necessary libraries

# %%
import datetime as dt
import numpy as np
import pandas as pd
import plotly.graph_objects as go

# %% [markdown]
# 2. Create a dataframe from the following link. Name it "sales_df".
# >'https://raw.githubusercontent.com/UrielBender/BigData/master/DataSets/supermarket_sales.csv'

# %%
sales_df=pd.read_csv('https://raw.githubusercontent.com/UrielBender/BigData/master/DataSets/supermarket_sales.csv')
sales_df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# ##Know your data
#
# Context
#
# The growth of supermarkets in most populated cities are increasing and market competitions are also high. The dataset is one of the historical sales of supermarket company which has recorded in 3 different branches for 3 months data. Predictive data analytics methods are easy to apply with this dataset.
#
# Attribute information
#
# **Invoice id**: Computer generated sales slip invoice identification number
#
# **Branch**: Branch of supercenter (3 branches are available identified by A, B and C).
#
# **City**: Location of supercenters
#
# **Customer type**: Type of customers, recorded by Members for customers using member card and Normal for without member card.
#
# **Gender**: Gender type of customer
#
# **Product line**: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
#
# **Unit price**: Price of each product in $
#
# **Quantity**: Number of products purchased by customer
#
# **Tax**: 5% tax fee for customer buying
#
# **Total**: Total price including tax
#
# **Date**: Date of purchase (Record available from January 2019 to March 2019)
#
# **Time**: Purchase time (10am to 9pm)
#
# **Payment**: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
#
# **COGS**: Cost of goods sold
#
# **Gross margin percentage**: Gross margin percentage
#
# Gross income: Gross income
#
# **Rating**: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)
#
# Purpose
#
# This dataset can be used for predictive data analytics purpose.
#
# **For example:**
#
# Given the type of customer, the date , and the branch - predict the rating that the customer would give.

# %% [markdown]
# 3. Print the head and info of the dataframe

# %%
sales_df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# 4. What is the dataframe's shape?

# %%
sales_df.shape
# Out:
# (1000, 17)

# %% [markdown]
# 5. What is the datatype of the 'Date' feature? convert it to datetime in the original dataframe

# %%
print(sales_df['Date'].dtype)
sales_df['Date'] = pd.to_datetime(sales_df['Date']) # Convert the 'Date' feature to datetime
print(sales_df['Date'].dtype)# Check the datatype of the 'Date' feature again
# Out:
# object
# datetime64[ns]

# %% [markdown]
# 6. How much money ('cogs' sum of all invoices) do male vs female spend in each branch? Plot the results in a stacked bar graph.
#
#
#  HINTS:
# >you will need to use more then once in some function from our few last lesson
#
# >sum is one of the aggregation functions you can use
#
# >Don't be shy and use the empty cells below

# %% [markdown]
# 7. Plot a line graph that describes the daily total sum of all invoices (sum of the 'total' feature by date).

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 8. What is the frequency of Payment type in each branch? Plot a pie chart for each payment type.

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 9.Bin the 'rating' feature values into 3 categories: 0-5,6-8,9-10 and plot a grouped bar chart that shows the rating category frequency by the type of customer (side by side).

# %%
sales_df['rating_category'] = pd.cut(sales_df['Rating'], bins=[0, 5, 8, 11], labels=['bad', 'good', 'excellent'])

sales_df.groupby(['Customer type', 'rating_category']).size().unstack()
# Out:
# rating_category  bad  good  excellent
# Customer type
# Member            98   246        157
# Normal            76   272        151

# %%
import matplotlib.pyplot as plt
sales_df['rating_category'] = pd.cut(sales_df['Rating'], bins=[0, 5, 8, 11], labels=['bad', 'good', 'excellent'])

sales_df.groupby(['Customer type', 'rating_category']).size().unstack().plot(kind='bar', stacked=False)
plt.xlabel('Customer type')
plt.ylabel('Rating Category Frequency')
plt.title('Rating Category Frequency by Customer Type')
plt.show()

# %% [markdown]
# [link text](https://)10. a. Are there any zero variance features in the DF? Drop the columns from the DF if such exist.

# %%
# Calculate the variance of each feature
variances = sales_df.var()

# Identify zero variance features
zero_variance_features = variances[variances == 0].index.tolist()

# Drop the zero variance features from the DataFrame
sales_df.drop(columns=zero_variance_features,inplace=True)

# Print the updated DataFrame
sales_df.head()
# Out:
# <ipython-input-12-f8f64b2ae609>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# ...

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# 10. b. Are there any unecessary features in the DF? (That don't add new information) Drop the columns from the DF if such exist.

# %%
sales_df = sales_df.drop(columns=["Tax 5%", "Product line", "cogs"])
# Print the updated DataFrame
sales_df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  Unit price  Quantity  \
# 0  750-67-8428      A     Yangon        Member  Female       74.69         7
# 1  226-31-3081      C  Naypyitaw        Normal  Female       15.28         5
# 2  631-41-3108      A     Yangon        Normal    Male       46.33         7
# 3  123-19-1176      A     Yangon        Member    Male       58.22         8
# 4  373-73-7910      A     Yangon        Normal    Male       86.31         7
#
#       Total       Date   Time      Payment  gross income  Rating  \
# 0  548.9715 2019-01-05  13:08      Ewallet       26.1415     9.1
# 1   80.2200 2019-03-08  10:29         Cash        3.8200     9.6
# 2  340.5255 2019-03-03  13:23  Credit card       16.2155     7.4
# 3  489.0480 2019-01-27  20:33      Ewallet       23.2880     8.4
# 4  634.3785 2019-02-08  10:37      Ewallet       30.2085     5.3
#
#   rating_category
# 0       excellent
# 1       excellent
# 2            good
# 3       excellent
# ...

# %% [markdown]
# 10. c. Print a correlation matrix, afterwards plot a heatmap of the correlation matrix.

# %%
corr_df = sales_df.corr()
corr_df
# Out:
# <ipython-input-14-e8bf62663603>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#               Unit price  Quantity     Total  gross income    Rating
# Unit price      1.000000  0.010778  0.633962      0.633962 -0.008778
# Quantity        0.010778  1.000000  0.705510      0.705510 -0.015815
# Total           0.633962  0.705510  1.000000      1.000000 -0.036442
# gross income    0.633962  0.705510  1.000000      1.000000 -0.036442
# Rating         -0.008778 -0.015815 -0.036442     -0.036442  1.000000

# %%
fig = go.Figure()
fig.add_traces(go.Heatmap(
    z=corr_df,
    x=corr_df.columns,
    y=corr_df.columns,
    zmax=1,
    zmin=0
))
fig.update_layout({
    'title':"Features Correlation Heatmap"
})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 10. d. Detect the highly correlated features. Drop them and plot the updated correlation heatmap.
#
# (Make sure not to delete all the features - Keep one of each correlated group)

# %%
corr_df_new=corr_df.drop(columns=['gross income'])
corr_df_new=corr_df_new.corr()
fig = go.Figure()
fig.add_traces(go.Heatmap(
    z=corr_df_new,
    x=corr_df_new.columns,
    y=corr_df_new.columns,
    zmax=1,
    zmin=0
))
fig.update_layout({
    'title':"Features Correlation Hetmap"
})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 11. Scale all the numeric date using SKLearn standardization module.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
columns_to_scale = ['Unit price', 'Quantity', 'Total', 'Rating']

# Scale the data
scaled_data = scaler.fit_transform(corr_df_new[columns_to_scale])

# Convert scaled data to DataFrame
scaled_data_df = pd.DataFrame(scaled_data, columns=columns_to_scale)

# Calculate standard deviation for each column
std_dev = corr_df_new[columns_to_scale].std()

# Divide each value by its standard deviation
scaled_data_df_std = scaled_data_df.div(std_dev)

scaled_data_df_std
# Out:
#    Unit price  Quantity     Total    Rating
# 0    1.810593 -0.869888  0.348955 -0.464632
# 1   -0.900013  1.584168  0.565753 -0.509026
# 2    0.810056  0.957090  1.053445 -0.986618
# 3   -1.720636 -1.671370 -1.968153  1.960277

# %% [markdown]
# 12. Plot and print the outliers in the scaled Total feature( or the other feature you decided not to drop in question 10 ).

# %%
import numpy as np
import plotly.graph_objects as go

c = ['hsl('+str(h)+',50%'+',50%)' for h in np.linspace(0, 360, 1)]  # Adjusted for only one color since we're plotting one column

fig = go.Figure()
fig.add_trace(go.Box(
    y=scaled_data_df_std['Total'],  # Selecting only the 'total' column
    marker_color=c[0],  # Using the first color from the list
    name='Total'  # Name the trace as 'Total'
))


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
